# %%
pip install markdown pyyaml
# Out:
# Requirement already satisfied: markdown in c:\users\lolic\anaconda3\lib\site-packages (3.4.1)
# Requirement already satisfied: pyyaml in c:\users\lolic\anaconda3\lib\site-packages (6.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import markdown
import yaml
import re

class Node:
    def __init__(self, id, name, content):
        self.id = id
        self.name = name
        self.content = content
        self.edges = []

class Edge:
    def __init__(self, source, target, link_type):
        self.source = source
        self.target = target
        self.link_type = link_type

def parse_markdown_file(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        content = file.read()

    # Extract front matter (YAML)
    front_matter = re.search(r'^---(.*?)---', content, re.DOTALL)
    if front_matter:
        front_matter_content = front_matter.group(1)
        metadata = yaml.safe_load(front_matter_content)
        content = content.replace(front_matter.group(0), '')
    else:
        metadata = {}

    # Extract links in the markdown content
    links = re.findall(r'\[\[([^\]]+)\]\]', content)

    return metadata, links, content

def create_graph_from_logseq(directory):
    nodes = {}
    edges = []

    # Parse each markdown file in the directory
    for filename in os.listdir(directory):
        if filename.endswith('.md'):
            file_path = os.path.join(directory, filename)
            metadata, links, content = parse_markdown_file(file_path)

            node_id = metadata.get('id', filename)
            node_name = metadata.get('title', filename.replace('.md', ''))
            node = Node(node_id, node_name, content)
            nodes[node_id] = node

            for link in links:
                target_node_name = link
                edge = Edge(node_id, target_node_name, 'link')
                node.edges.append(edge)
                edges.append(edge)

    return nodes, edges

# Example usage
logseq_directory = r'C:\Users\lolic\OneDrive\Desktop\MediaCity Immersive Innovation Hub(Dreamlab)\Knowledge graph\logseq_local_C__Keep Productive_markdown_1719235033\Keep Productive_markdown_1719235033'
nodes, edges = create_graph_from_logseq(logseq_directory)

# %%
import bpy

# Assuming `nodes` and `edges` are from the previous script
# Example dummy nodes and edges for illustration
nodes = {
    '1': Node('1', 'Node1', 'Content1'),
    '2': Node('2', 'Node2', 'Content2'),
}
edges = [Edge('1', '2', 'link')]

def create_blender_objects(nodes, edges):
    for node_id, node in nodes.items():
        bpy.ops.mesh.primitive_uv_sphere_add(radius=1, location=(node_id * 2, 0, 0))
        obj = bpy.context.object
        obj.name = node.name
        node.blender_object = obj

    for edge in edges:
        source_node = nodes[edge.source]
        target_node = nodes[edge.target]
        
        if hasattr(source_node, 'blender_object') and hasattr(target_node, 'blender_object'):
            start = source_node.blender_object.location
            end = target_node.blender_object.location

            bpy.ops.mesh.primitive_cylinder_add(
                radius=0.1,
                depth=(end - start).length,
                location=(start + end) / 2
            )
            obj = bpy.context.object
            obj.name = f"{source_node.name}_to_{target_node.name}"
            obj.rotation_euler = (end - start).to_track_quat('Z', 'Y').to_euler()
            
# Run the function to create objects
create_blender_objects(nodes, edges)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import bpy
#       3 # Assuming `nodes` and `edges` are from the previous script
#       4 # Example dummy nodes and edges for illustration
#       5 nodes = {
#       6     '1': Node('1', 'Node1', 'Content1'),
#       7     '2': Node('2', 'Node2', 'Content2'),
#       8 }
#
# ModuleNotFoundError: No module named 'bpy'

# %%
import os
import re
import yaml
import json

class Node:
    def __init__(self, id, name, content):
        self.id = id
        self.name = name
        self.content = content
        self.edges = []

class Edge:
    def __init__(self, source, target, link_type):
        self.source = source
        self.target = target
        self.link_type = link_type

def parse_markdown_file(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        content = file.read()

    # Extract front matter (YAML)
    front_matter = re.search(r'^---(.*?)---', content, re.DOTALL)
    if front_matter:
        front_matter_content = front_matter.group(1)
        metadata = yaml.safe_load(front_matter_content)
        content = content.replace(front_matter.group(0), '')
    else:
        metadata = {}

    # Extract links in the markdown content
    links = re.findall(r'\[\[([^\]]+)\]\]', content)

    return metadata, links, content

def create_graph_from_logseq(directory):
    nodes = {}
    edges = []

    # Parse each markdown file in the directory
    for filename in os.listdir(directory):
        if filename.endswith('.md'):
            file_path = os.path.join(directory, filename)
            metadata, links, content = parse_markdown_file(file_path)

            node_id = metadata.get('id', filename)
            node_name = metadata.get('title', filename.replace('.md', ''))
            node = Node(node_id, node_name, content)
            nodes[node_id] = node

            for link in links:
                target_node_name = link
                edge = Edge(node_id, target_node_name, 'link')
                node.edges.append(edge)
                edges.append(edge)

    return nodes, edges

def node_to_dict(node):
    return {
        'id': node.id,
        'name': node.name,
        'content': node.content,
        'edges': [{'source': edge.source, 'target': edge.target, 'link_type': edge.link_type} for edge in node.edges]
    }

def save_to_json(nodes, edges, nodes_file_path, edges_file_path):
    nodes_list = [node_to_dict(node) for node in nodes.values()]
    edges_list = [{'source': edge.source, 'target': edge.target, 'link_type': edge.link_type} for edge in edges]

    with open(nodes_file_path, 'w', encoding='utf-8') as nodes_file:
        json.dump(nodes_list, nodes_file, ensure_ascii=False, indent=4)

    with open(edges_file_path, 'w', encoding='utf-8') as edges_file:
        json.dump(edges_list, edges_file, ensure_ascii=False, indent=4)

# Example usage
logseq_directory = r'C:\Users\lolic\OneDrive\Desktop\MediaCity Immersive Innovation Hub(Dreamlab)\Knowledge graph\logseq_local_C__Keep Productive_markdown_1719235033\Keep Productive_markdown_1719235033'
nodes, edges = create_graph_from_logseq(logseq_directory)

# Save nodes and edges to JSON files
nodes_file_path = 'nodes.json'
edges_file_path = 'edges.json'
save_to_json(nodes, edges, nodes_file_path, edges_file_path)

# %%
import os
import re
import yaml
import json

class Node:
    def __init__(self, id, name, content):
        self.id = id
        self.name = name
        self.content = content
        self.edges = []

class Edge:
    def __init__(self, source, target, link_type):
        self.source = source
        self.target = target
        self.link_type = link_type

def parse_markdown_file(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        content = file.read()

    # Extract front matter (YAML)
    front_matter = re.search(r'^---(.*?)---', content, re.DOTALL)
    if front_matter:
        front_matter_content = front_matter.group(1)
        metadata = yaml.safe_load(front_matter_content)
        content = content.replace(front_matter.group(0), '')
    else:
        metadata = {}

    # Extract links in the markdown content
    links = re.findall(r'\[\[([^\]]+)\]\]', content)

    return metadata, links, content

def create_graph_from_logseq(directory):
    nodes = {}
    edges = []

    # Function to parse files in a given folder
    def parse_folder(folder):
        for filename in os.listdir(folder):
            if filename.endswith('.md'):
                file_path = os.path.join(folder, filename)
                print(f"Parsing file: {file_path}")
                metadata, links, content = parse_markdown_file(file_path)
                print(f"Metadata: {metadata}")
                print(f"Links: {links}")

                node_id = metadata.get('id', filename)
                node_name = metadata.get('title', filename.replace('.md', ''))
                node = Node(node_id, node_name, content)
                nodes[node_id] = node

                for link in links:
                    target_node_name = link
                    edge = Edge(node_id, target_node_name, 'link')
                    node.edges.append(edge)
                    edges.append(edge)

    # Parse markdown files in 'journals' and 'pages' folders
    journals_folder = os.path.join(directory, 'journals')
    pages_folder = os.path.join(directory, 'pages')

    if os.path.exists(journals_folder):
        parse_folder(journals_folder)

    if os.path.exists(pages_folder):
        parse_folder(pages_folder)

    return nodes, edges

def node_to_dict(node):
    return {
        'id': node.id,
        'name': node.name,
        'content': node.content,
        'edges': [{'source': edge.source, 'target': edge.target, 'link_type': edge.link_type} for edge in node.edges]
    }

def save_to_json(nodes, edges, nodes_file_path, edges_file_path):
    nodes_list = [node_to_dict(node) for node in nodes.values()]
    edges_list = [{'source': edge.source, 'target': edge.target, 'link_type': edge.link_type} for edge in edges]

    with open(nodes_file_path, 'w', encoding='utf-8') as nodes_file:
        json.dump(nodes_list, nodes_file, ensure_ascii=False, indent=4)

    with open(edges_file_path, 'w', encoding='utf-8') as edges_file:
        json.dump(edges_list, edges_file, ensure_ascii=False, indent=4)

# Example usage
logseq_directory = r'C:\Users\lolic\OneDrive\Desktop\MediaCity Immersive Innovation Hub(Dreamlab)\Knowledge graph\logseq_local_C__Keep Productive_markdown_1719235033\Keep Productive_markdown_1719235033'
nodes, edges = create_graph_from_logseq(logseq_directory)
print(f"Nodes: {nodes}")
print(f"Edges: {edges}")

# Save nodes and edges to JSON files
nodes_file_path = 'nodes.json'
edges_file_path = 'edges.json'
save_to_json(nodes, edges, nodes_file_path, edges_file_path)
# Out:
# Parsing file: C:\Users\lolic\OneDrive\Desktop\MediaCity Immersive Innovation Hub(Dreamlab)\Knowledge graph\logseq_local_C__Keep Productive_markdown_1719235033\Keep Productive_markdown_1719235033\journals\2024_04_28.md
# Metadata: {}
# Links: ['beginner guide', 'collaboration', '[research workflows', 'Chatbot', 'oogabooga', 'ollama 8b', 'AlwayReddy', 'Ollama', 'Data Scientist Roadmap 2024', 'Datasette', 'comfyui', 'Labor Market', 'Large Language Models', 'Artificial Intelligence', 'Economic Growth', 'Global Economics Analyst']
# Parsing file: C:\Users\lolic\OneDrive\Desktop\MediaCity Immersive Innovation Hub(Dreamlab)\Knowledge graph\logseq_local_C__Keep Productive_markdown_1719235033\Keep Productive_markdown_1719235033\journals\2024_04_29.md
# Metadata: {}
# Links: ['wolframs', 'Large Language Models', 'Mentor', 'Teese', 'ChatGPT Prompt Engineering for Developers', 'large language model', 'LLM', 'ChatGPT', 'OpenAI']
# Parsing file: C:\Users\lolic\OneDrive\Desktop\MediaCity Immersive Innovation Hub(Dreamlab)\Knowledge graph\logseq_local_C__Keep Productive_markdown_1719235033\Keep Productive_markdown_1719235033\journals\2024_04_30.md
# Metadata: {}
# Links: ['Job', 'tasks', 'Occupation keyword', 'Gen AI', 'ChatGPT Prompt Engineering for Developers', 'Model Limitations', 'Hallucinations']
# Parsing file: C:\Users\lolic\OneDrive\Desktop\MediaCity Immersive Innovation Hub(Dreamlab)\Knowledge graph\logseq_local_C__Keep Productive_markdown_1719235033\Keep Productive_markdown_1719235033\journals\2024_05_04.md
# Metadata: {}
# Links: []
# Parsing file: C:\Users\lolic\OneDrive\Desktop\MediaCity Immersive Innovation Hub(Dreamlab)\Knowledge graph\logseq_local_C__Keep Productive_markdown_1719235033\Keep Productive_markdown_1719235033\journals\2024_05_12.md
# Metadata: {}
# Links: ['Power BI channel project', 'Nicola Sagay', 'Sowjanya Surapneni', 'Jing Li']
# Parsing file: C:\Users\lolic\OneDrive\Desktop\MediaCity Immersive Innovation Hub(Dreamlab)\Knowledge graph\logseq_local_C__Keep Productive_markdown_1719235033\Keep Productive_markdown_1719235033\journals\2024_05_16.md
# Metadata: {}
# Links: []
# Parsing file: C:\Users\lolic\OneDrive\Desktop\MediaCity Immersive Innovation Hub(Dreamlab)\Knowledge graph\logseq_local_C__Keep Productive_markdown_1719235033\Keep Productive_markdown_1719235033\journals\2024_05_17.md
# Metadata: {}
# Links: ['Lab Technician', 'MediaCityUK', 'MediaCity', 'Interview preparation', 'Catch 22 Data & Insight Analyst', 'Interview preparation', 'Project', 'Regression project', 'Classification project']
# Parsing file: C:\Users\lolic\OneDrive\Desktop\MediaCity Immersive Innovation Hub(Dreamlab)\Knowledge graph\logseq_local_C__Keep Productive_markdown_1719235033\Keep Productive_markdown_1719235033\journals\2024_05_18.md
# Metadata: {}
# Links: ['Machine Learning course', 'AI', 'ML', 'DS', 'Artificial Intelligence', 'Machine Learning', 'Data Science', 'Features', 'Machine Learning', 'Qualitative', 'nominal data', 'ONE-HOT ENCODING', 'ordinal data', 'Quantitative', 'Output', 'prediction', 'MODEL', 'loss']
# Parsing file: C:\Users\lolic\OneDrive\Desktop\MediaCity Immersive Innovation Hub(Dreamlab)\Knowledge graph\logseq_local_C__Keep Productive_markdown_1719235033\Keep Productive_markdown_1719235033\journals\2024_05_19.md
# Metadata: {}
# Links: ['Knelyfe labs']
# Parsing file: C:\Users\lolic\OneDrive\Desktop\MediaCity Immersive Innovation Hub(Dreamlab)\Knowledge graph\logseq_local_C__Keep Productive_markdown_1719235033\Keep Productive_markdown_1719235033\journals\2024_06_03.md
# Metadata: {}
# Links: ['Knelyfe Labs']
# Parsing file: C:\Users\lolic\OneDrive\Desktop\MediaCity Immersive Innovation Hub(Dreamlab)\Knowledge graph\logseq_local_C__Keep Productive_markdown_1719235033\Keep Productive_markdown_1719235033\journals\2024_06_04.md
# Metadata: {}
# Links: ['MITIH']
# Parsing file: C:\Users\lolic\OneDrive\Desktop\MediaCity Immersive Innovation Hub(Dreamlab)\Knowledge graph\logseq_local_C__Keep Productive_markdown_1719235033\Keep Productive_markdown_1719235033\journals\2024_06_06.md
# Metadata: {}
# Links: ['Blender', 'Navigation tools']
# Parsing file: C:\Users\lolic\OneDrive\Desktop\MediaCity Immersive Innovation Hub(Dreamlab)\Knowledge graph\logseq_local_C__Keep Productive_markdown_1719235033\Keep Productive_markdown_1719235033\journals\2024_06_07.md
# Metadata: {}
# Links: ['plotly', 'Immersive analytics', 'virtual reality', 'augmented reality', '3D rendering', '3D modelling', '3D animation']
# Parsing file: C:\Users\lolic\OneDrive\Desktop\MediaCity Immersive Innovation Hub(Dreamlab)\Knowledge graph\logseq_local_C__Keep Productive_markdown_1719235033\Keep Productive_markdown_1719235033\journals\2024_06_14.md
# Metadata: {}
# Links: ['Github', 'Git', 'Github desktop', 'Spring', 'Knowledge Graph', 'data spring system knowledge graph', 'Knowledge Graphs', 'Data', 'Data Science', 'Knowledge Graphs', 'visualizations', 'data and analytics innovations', 'WIKIDATA', 'SPARQL']
# Parsing file: C:\Users\lolic\OneDrive\Desktop\MediaCity Immersive Innovation Hub(Dreamlab)\Knowledge graph\logseq_local_C__Keep Productive_markdown_1719235033\Keep Productive_markdown_1719235033\journals\2024_06_17.md
# Metadata: {}
# Links: ['3d nodes project', 'Omniverse', '11Elevenlabs', 'AI Voice', 'Dreamlab podcast', 'Showrunner', 'Unreal engine avalanche', 'EQ-bench', 'evaluation Logseq', 'Ontology', 'Knowledge Graph', 'Mermaid diagram', 'mermaid live', 'Three.js', 'Spring class', 'Brendan Dawes', 'data visualisation', 'Universal Scene Description', 'USD']
# Parsing file: C:\Users\lolic\OneDrive\Desktop\MediaCity Immersive Innovation Hub(Dreamlab)\Knowledge graph\logseq_local_C__Keep Productive_markdown_1719235033\Keep Productive_markdown_1719235033\journals\2024_06_19.md
# Metadata: {}
# Links: ['API', 'AGI', 'gene editing', 'genetic defects', 'Quantum computing', 'cryptographic', 'molecure', 'analyze vast datasets', 'Neuralink', 'Humanoid robots', 'Generative AI', 'LLM smashing']
# Parsing file: C:\Users\lolic\OneDrive\Desktop\MediaCity Immersive Innovation Hub(Dreamlab)\Knowledge graph\logseq_local_C__Keep Productive_markdown_1719235033\Keep Productive_markdown_1719235033\journals\2024_06_20.md
# Metadata: {}
# Links: ['MITIH', 'Neural networks', 'Knowledge Graphs']
# Parsing file: C:\Users\lolic\OneDrive\Desktop\MediaCity Immersive Innovation Hub(Dreamlab)\Knowledge graph\logseq_local_C__Keep Productive_markdown_1719235033\Keep Productive_markdown_1719235033\journals\2024_06_21.md
# Metadata: {}
# Links: ['Gephi', 'API']
# Parsing file: C:\Users\lolic\OneDrive\Desktop\MediaCity Immersive Innovation Hub(Dreamlab)\Knowledge graph\logseq_local_C__Keep Productive_markdown_1719235033\Keep Productive_markdown_1719235033\journals\2024_06_22.md
# Metadata: {}
# Links: ['USD', 'API', 'Neo4j', 'Space Tourism', 'Lunar Tourism', 'Internet of Things', 'Mixed reality', '3D printing', 'Solid-state batteries', 'Fusion power', 'Blockchain', 'lab-grown meat', 'Transformers']
# Parsing file: C:\Users\lolic\OneDrive\Desktop\MediaCity Immersive Innovation Hub(Dreamlab)\Knowledge graph\logseq_local_C__Keep Productive_markdown_1719235033\Keep Productive_markdown_1719235033\journals\2024_06_24.md
# Metadata: {}
# Links: ['Blender', 'markdown files', 'Spring']
# Parsing file: C:\Users\lolic\OneDrive\Desktop\MediaCity Immersive Innovation Hub(Dreamlab)\Knowledge graph\logseq_local_C__Keep Productive_markdown_1719235033\Keep Productive_markdown_1719235033\pages\collaboration.md
# Metadata: {}
# Links: []
# Parsing file: C:\Users\lolic\OneDrive\Desktop\MediaCity Immersive Innovation Hub(Dreamlab)\Knowledge graph\logseq_local_C__Keep Productive_markdown_1719235033\Keep Productive_markdown_1719235033\pages\contents.md
# Metadata: {}
# Links: []
# Nodes: {'2024_04_28.md': <__main__.Node object at 0x00000205DA7BE290>, '2024_04_29.md': <__main__.Node object at 0x00000205DA7BED90>, '2024_04_30.md': <__main__.Node object at 0x00000205DA7BEFD0>, '2024_05_04.md': <__main__.Node object at 0x00000205DA7BF850>, '2024_05_12.md': <__main__.Node object at 0x00000205DA7BFB50>, '2024_05_16.md': <__main__.Node object at 0x00000205DA7BFA90>, '2024_05_17.md': <__main__.Node object at 0x00000205DA7BF990>, '2024_05_18.md': <__main__.Node object at 0x00000205DA7BDD10>, '2024_05_19.md': <__main__.Node object at 0x00000205DA7BD990>, '2024_06_03.md': <__main__.Node object at 0x00000205DA7BFE90>, '2024_06_04.md': <__main__.Node object at 0x00000205DA7BE410>, '2024_06_06.md': <__main__.Node object at 0x00000205DA7BEED0>, '2024_06_07.md': <__main__.Node object at 0x00000205DA7BFC90>, '2024_06_14.md': <__main__.Node object at 0x00000205DA7E8090>, '2024_06_17.md': <__main__.Node object at 0x00000205DA7E8810>, '2024_06_19.md': <__main__.Node object at 0x00000205DA7E8750>, '2024_06_20.md': <__main__.Node object at 0x00000205DA7E9A90>, '2024_06_21.md': <__main__.Node object at 0x00000205DA7E9C50>, '2024_06_22.md': <__main__.Node object at 0x00000205DA7E9ED0>, '2024_06_24.md': <__main__.Node object at 0x00000205DA7EA590>, 'collaboration.md': <__main__.Node object at 0x00000205DA7EA750>, 'contents.md': <__main__.Node object at 0x00000205DA7EA9D0>}
# Edges: [<__main__.Edge object at 0x00000205D99DD2D0>, <__main__.Edge object at 0x00000205DA007B50>, <__main__.Edge object at 0x00000205DA7BEA50>, <__main__.Edge object at 0x00000205DA7BE190>, <__main__.Edge object at 0x00000205DA7BE050>, <__main__.Edge object at 0x00000205DA7BE850>, <__main__.Edge object at 0x00000205DA7BE390>, <__main__.Edge object at 0x00000205DA7BE510>, <__main__.Edge object at 0x00000205DA7BE790>, <__main__.Edge object at 0x00000205DA7BE490>, <__main__.Edge object at 0x00000205DA7BE2D0>, <__main__.Edge object at 0x00000205DA7BEB90>, <__main__.Edge object at 0x00000205DA7BEC10>, <__main__.Edge object at 0x00000205DA7BC050>, <__main__.Edge object at 0x00000205DA7BEB10>, <__main__.Edge object at 0x00000205DA7BED10>, <__main__.Edge object at 0x00000205DA7BEB50>, <__main__.Edge object at 0x00000205DA7BEA90>, <__main__.Edge object at 0x00000205DA7BCBD0>, <__main__.Edge object at 0x00000205DA7BEDD0>, <__main__.Edge object